# %%
import pandas as pd #biblioteca utilizada para trabalhar com dataframes
import numpy as np #biblioteca utilizada no tratamento de matrizes e vetores
import seaborn as sn #biblioteca utilizada pra plotar os gráficos em um formato mais "elegante"
import matplotlib.pyplot as plt  #biblioteca utilizada para plotar os gráficos

# %%
bike_sharing=pd.read_csv('bike-sharing.csv') #carregamento do df 
bike_sharing.head(10)  #exibindo as 10 primeiras linhas do df
# Out:
#      datetime  rec_id  season  year  month  hour  is_holiday  weekday  \
# 0  2011-01-01       1       1     0      1     0           0        6
# 1  2011-01-01       2       1     0      1     1           0        6
# 2  2011-01-01       3       1     0      1     2           0        6
# 3  2011-01-01       4       1     0      1     3           0        6
# 4  2011-01-01       5       1     0      1     4           0        6
# 5  2011-01-01       6       1     0      1     5           0        6
# 6  2011-01-01       7       1     0      1     6           0        6
# 7  2011-01-01       8       1     0      1     7           0        6
# 8  2011-01-01       9       1     0      1     8           0        6
# 9  2011-01-01      10       1     0      1     9           0        6
#
#    is_workingday  weather_condition  temp   atemp  humidity  windspeed  \
# 0              0                  1  0.24  0.2879      0.81     0.0000
# ...

# %%
bike_sharing.describe().T
# Out:
#                      count         mean          std   min        25%  \
# rec_id             17379.0  8690.000000  5017.029500  1.00  4345.5000
# season             17379.0     2.501640     1.106918  1.00     2.0000
# year               17379.0     0.502561     0.500008  0.00     0.0000
# month              17379.0     6.537775     3.438776  1.00     4.0000
# hour               17379.0    11.546752     6.914405  0.00     6.0000
# is_holiday         17379.0     0.028770     0.167165  0.00     0.0000
# weekday            17379.0     3.003683     2.005771  0.00     1.0000
# is_workingday      17379.0     0.682721     0.465431  0.00     0.0000
# weather_condition  17379.0     1.425283     0.639357  1.00     1.0000
# temp               17379.0     0.496987     0.192556  0.02     0.3400
# atemp              17379.0     0.475775     0.171850  0.00     0.3333
# humidity           17379.0     0.627229     0.192930  0.00     0.4800
# ...

# %%
print('Dimensão do dataframe: {}'.format(bike_sharing.shape))
# Out:
# Dimensão do dataframe: (17379, 17)

# %%
print(bike_sharing['windspeed'].mean())
# Out:
# 0.1900976063064631

# %%
print(bike_sharing['temp'].mean())
# Out:
# 0.4969871684216586

# %%
bike_sharing[
    (bike_sharing['datetime'] >= '2011-01-01') & 
    (bike_sharing['datetime'] < '2012-01-01')
]
# Out:
#         datetime  rec_id  season  year  month  hour  is_holiday  weekday  \
# 0     2011-01-01       1       1     0      1     0           0        6
# 1     2011-01-01       2       1     0      1     1           0        6
# 2     2011-01-01       3       1     0      1     2           0        6
# 3     2011-01-01       4       1     0      1     3           0        6
# 4     2011-01-01       5       1     0      1     4           0        6
# ...          ...     ...     ...   ...    ...   ...         ...      ...
# 8640  2011-12-31    8641       1     0     12    19           0        6
# 8641  2011-12-31    8642       1     0     12    20           0        6
# 8642  2011-12-31    8643       1     0     12    21           0        6
# 8643  2011-12-31    8644       1     0     12    22           0        6
# 8644  2011-12-31    8645       1     0     12    23           0        6
#
#       is_workingday  weather_condition  temp   atemp  humidity  windspeed  \
# ...

# %%
bike_sharing[
    (bike_sharing['datetime'] >= '2012-01-01') & 
    (bike_sharing['datetime'] < '2013-01-01')
]
# Out:
#          datetime  rec_id  season  year  month  hour  is_holiday  weekday  \
# 8645   2012-01-01    8646       1     1      1     0           0        0
# 8646   2012-01-01    8647       1     1      1     1           0        0
# 8647   2012-01-01    8648       1     1      1     2           0        0
# 8648   2012-01-01    8649       1     1      1     3           0        0
# 8649   2012-01-01    8650       1     1      1     4           0        0
# ...           ...     ...     ...   ...    ...   ...         ...      ...
# 17374  2012-12-31   17375       1     1     12    19           0        1
# 17375  2012-12-31   17376       1     1     12    20           0        1
# 17376  2012-12-31   17377       1     1     12    21           0        1
# 17377  2012-12-31   17378       1     1     12    22           0        1
# 17378  2012-12-31   17379       1     1     12    23           0        1
#
#        is_workingday  weather_condition  temp   atemp  humidity  windspeed  \
# ...

# %%
bike_sharing[
    (bike_sharing['datetime'] >= '2011-01-01') & 
    (bike_sharing['datetime'] < '2012-01-01')
]["total_count"].sum()
# Out:
# 1243103

# %%
bike_sharing[
    (bike_sharing['datetime'] >= '2012-01-01') & 
    (bike_sharing['datetime'] < '2013-01-01')
]["total_count"].sum()
# Out:
# 2049576

# %%
bike_sharing.groupby(['season'])["total_count"].sum()
# Out:
# season
# 1     471348
# 2     918589
# 3    1061129
# 4     841613
# Name: total_count, dtype: int64

# %%
bike_sharing.groupby(['season'])["total_count"].mean()
# Out:
# season
# 1    111.114569
# 2    208.344069
# 3    236.016237
# 4    198.868856
# Name: total_count, dtype: float64

# %%
bike_sharing.groupby(['hour'])["total_count"].mean()
# Out:
# hour
# 0      53.898072
# 1      33.375691
# 2      22.869930
# 3      11.727403
# 4       6.352941
# 5      19.889819
# 6      76.044138
# 7     212.064649
# 8     359.011004
# 9     219.309491
# 10    173.668501
# 11    208.143054
# 12    253.315934
# 13    253.661180
# 14    240.949246
# 15    251.233196
# 16    311.983562
# 17    461.452055
# 18    425.510989
# 19    311.523352
# 20    226.030220
# 21    172.314560
# 22    131.335165
# 23     87.831044
# Name: total_count, dtype: float64

# %%
bike_sharing.groupby(['weekday'])["total_count"].mean()
# Out:
# weekday
# 0    177.468825
# 1    183.744655
# 2    191.238891
# 3    191.130505
# 4    196.436665
# 5    196.135907
# 6    190.209793
# Name: total_count, dtype: float64

# %%
bike_sharing[
    (bike_sharing['weekday'] == 3)
][{"total_count", "hour"}].groupby(['hour'])["total_count"].mean()
# Out:
# hour
# 0      34.557692
# 1      15.336538
# 2       7.813725
# 3       4.888889
# 4       4.968750
# 5      25.750000
# 6     107.807692
# 7     303.980769
# 8     488.326923
# 9     238.528846
# 10    131.894231
# 11    152.201923
# 12    193.903846
# 13    185.826923
# 14    170.548077
# 15    181.288462
# 16    272.961538
# 17    513.144231
# 18    494.029126
# 19    357.504854
# 20    256.660194
# 21    194.669903
# 22    143.689320
# 23     83.737864
# Name: total_count, dtype: float64

# %%
bike_sharing[
    (bike_sharing['weekday'] == 6)
][{"total_count", "hour"}].groupby(['hour'])["total_count"].mean()
# Out:
# hour
# 0      94.304762
# 1      67.780952
# 2      50.495238
# 3      22.885714
# 4       7.657143
# 5       8.291262
# 6      21.000000
# 7      45.961905
# 8     114.476190
# 9     186.790476
# 10    263.723810
# 11    328.609524
# 12    375.380952
# 13    385.371429
# 14    381.333333
# 15    382.428571
# 16    366.142857
# 17    334.409524
# 18    292.048077
# 19    239.932692
# 20    180.865385
# 21    156.000000
# 22    139.663462
# 23    115.855769
# Name: total_count, dtype: float64
